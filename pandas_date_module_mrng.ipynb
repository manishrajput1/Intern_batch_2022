# %%
import pandas as pd

# %% [markdown]
# # DateTime Module

# %%
dates=pd.date_range('20220401','20220530') # yymmdd

# %%
pd.date_range('20220401',periods=365)
# Out:
# DatetimeIndex(['2022-04-01', '2022-04-02', '2022-04-03', '2022-04-04',
#                '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08',
#                '2022-04-09', '2022-04-10',
#                ...
#                '2023-03-22', '2023-03-23', '2023-03-24', '2023-03-25',
#                '2023-03-26', '2023-03-27', '2023-03-28', '2023-03-29',
#                '2023-03-30', '2023-03-31'],
#               dtype='datetime64[ns]', length=365, freq='D')

# %%
pd.date_range('20220401',periods=100,freq='')
# Out:
# DatetimeIndex([       '2022-04-01 00:00:00', '2022-04-01 00:00:00.001000',
#                '2022-04-01 00:00:00.002000', '2022-04-01 00:00:00.003000',
#                '2022-04-01 00:00:00.004000', '2022-04-01 00:00:00.005000',
#                '2022-04-01 00:00:00.006000', '2022-04-01 00:00:00.007000',
#                '2022-04-01 00:00:00.008000', '2022-04-01 00:00:00.009000',
#                '2022-04-01 00:00:00.010000', '2022-04-01 00:00:00.011000',
#                '2022-04-01 00:00:00.012000', '2022-04-01 00:00:00.013000',
#                '2022-04-01 00:00:00.014000', '2022-04-01 00:00:00.015000',
#                '2022-04-01 00:00:00.016000', '2022-04-01 00:00:00.017000',
#                '2022-04-01 00:00:00.018000', '2022-04-01 00:00:00.019000',
#                '2022-04-01 00:00:00.020000', '2022-04-01 00:00:00.021000',
#                '2022-04-01 00:00:00.022000', '2022-04-01 00:00:00.023000',
# ...

# %%
pd.date_range?

# %%
dates
# Out:
# DatetimeIndex(['2022-04-01', '2022-04-02', '2022-04-03', '2022-04-04',
#                '2022-04-05', '2022-04-06', '2022-04-07', '2022-04-08',
#                '2022-04-09', '2022-04-10', '2022-04-11', '2022-04-12',
#                '2022-04-13', '2022-04-14', '2022-04-15', '2022-04-16',
#                '2022-04-17', '2022-04-18', '2022-04-19', '2022-04-20',
#                '2022-04-21', '2022-04-22', '2022-04-23', '2022-04-24',
#                '2022-04-25', '2022-04-26', '2022-04-27', '2022-04-28',
#                '2022-04-29', '2022-04-30', '2022-05-01', '2022-05-02',
#                '2022-05-03', '2022-05-04', '2022-05-05', '2022-05-06',
#                '2022-05-07', '2022-05-08', '2022-05-09', '2022-05-10',
#                '2022-05-11', '2022-05-12', '2022-05-13', '2022-05-14',
#                '2022-05-15', '2022-05-16', '2022-05-17', '2022-05-18',
#                '2022-05-19', '2022-05-20', '2022-05-21', '2022-05-22',
# ...

# %%
import random
df=pd.DataFrame({'name':[chr(i) for i in range(65,91)],'temp':[random.randint(30,50) for i in range(65,91)]})

# %%
date=pd.date_range('20220401',periods=26)

# %%
df['dates']=date

# %%
df['dayofweek']=df['dates'].dt.dayofweek

# %%
df['dayofyear']=df['dates'].dt.dayofyear

# %%
df['dayname']=df['dates'].dt.day_name()

# %%
df[df['weekname']!='Sunday']
# Out:
#    name  temp      dates  dayofweek  dayofyear   weekname    dayname
# 0     A    38 2022-04-01          4         91     Friday     Friday
# 1     B    44 2022-04-02          5         92   Saturday   Saturday
# 3     D    48 2022-04-04          0         94     Monday     Monday
# 4     E    38 2022-04-05          1         95    Tuesday    Tuesday
# 5     F    37 2022-04-06          2         96  Wednesday  Wednesday
# 6     G    46 2022-04-07          3         97   Thursday   Thursday
# 7     H    32 2022-04-08          4         98     Friday     Friday
# 8     I    50 2022-04-09          5         99   Saturday   Saturday
# 10    K    49 2022-04-11          0        101     Monday     Monday
# 11    L    48 2022-04-12          1        102    Tuesday    Tuesday
# 12    M    48 2022-04-13          2        103  Wednesday  Wednesday
# 13    N    40 2022-04-14          3        104   Thursday   Thursday
# 14    O    31 2022-04-15          4        105     Friday     Friday
# ...

# %%
df.index=df['dates']

# %%
df['2020-04-10':'2022-04-20']
# Out:
#            name  temp      dates  dayofweek  dayofyear   weekname    dayname
# dates
# 2022-04-01    A    38 2022-04-01          4         91     Friday     Friday
# 2022-04-02    B    44 2022-04-02          5         92   Saturday   Saturday
# 2022-04-03    C    48 2022-04-03          6         93     Sunday     Sunday
# 2022-04-04    D    48 2022-04-04          0         94     Monday     Monday
# 2022-04-05    E    38 2022-04-05          1         95    Tuesday    Tuesday
# 2022-04-06    F    37 2022-04-06          2         96  Wednesday  Wednesday
# 2022-04-07    G    46 2022-04-07          3         97   Thursday   Thursday
# 2022-04-08    H    32 2022-04-08          4         98     Friday     Friday
# 2022-04-09    I    50 2022-04-09          5         99   Saturday   Saturday
# 2022-04-10    J    38 2022-04-10          6        100     Sunday     Sunday
# 2022-04-11    K    49 2022-04-11          0        101     Monday     Monday
# ...

# %%
# sqlalchemy
# sql to pandas  | pandas to sql
