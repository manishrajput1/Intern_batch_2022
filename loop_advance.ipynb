# %%
for row in range(7):
    for col in range(4):
        if (row==0 and col!=0) or (row==6 and col!=3) or (row==1 and col==0) or (row==2 and col==0) or (row==3 and col==1)or (row==3 and col==2) or (row==4 and col==3)or (row==5 and col==3):
            print('*',end=' ')
        else:
            print(end='  ')
    print()
# Out:
#   * * *
# *
# *
#   * *
#       *
#       *
# * * *

# %%
n=int(input('Enter odd value: '))
if (n%2 and  3<n<50):
    
    
    for row in range(n):
        for col in range(n):
            if row==n//2 or col==n//2 or (row==0 and col>n//2) or (col==n-1 and row>n//2) or (col==0 and row<n//2) or (row==n-1 and col<n//2):
                print('*',end=' ')
            else:
                print(end='  ')
        print()
    
    
else:
    print('please enter odd number... or less number')
# Out:
# Enter odd value: 15
# *             * * * * * * * *
# *             *
# *             *
# *             *
# *             *
# *             *
# *             *
# * * * * * * * * * * * * * * *
#               *             *
#               *             *
#               *             *
#               *             *
#               *             *
#               *             *
# * * * * * * * *             *

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rmani'

# %%
os.chdir('C:\\Users\\rmani\\Desktop')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\rmani\\Desktop'

# %%
os.listdir()
# Out:
# ['1294266.png',
#  'apply.txt',
#  'CentOS 8 64-bit-2022-02-01-20-14-22.png',
#  'CentOS 8 64-bit-2022-02-01-20-14-58.png',
#  'CentOS 8 64-bit-2022-02-01-20-17-10.png',
#  'CentOS 8 64-bit-2022-02-01-20-41-45.png',
#  'CentOS 8 64-bit-2022-02-01-20-41-51.png',
#  'CentOS 8 64-bit-2022-02-01-20-42-05.png',
#  'CentOS 8 64-bit-2022-02-01-20-42-14.png',
#  'CentOS 8 64-bit-2022-02-01-20-42-21.png',
#  'CentOS 8 64-bit-2022-02-01-20-43-41.png',
#  'chat.py',
#  'chatbot',
#  'client.py',
#  'contact.html',
#  'database.txt',
#  'demo.html',
#  'demo.txt',
#  'design.html',
#  'desktop.ini',
#  'django_command.txt',
#  'djnago_classes',
#  'document_management_system',
#  'document_management_system.zip',
#  'download.png',
#  'drive_lecture.txt',
#  'ecom',
#  'ecom.zip',
#  'final_hadoop.txt',
#  'first_hmtl_class.html',
#  'git_demo',
#  'harsh.txt',
#  'hdfs_commands.txt',
#  'home3-classic.html',
#  'HTTrack Website Copier.lnk',
#  'imgdata.txt',
#  'imgdata1.txt',
# ...

# %%
os.chdir('C:\\Users\\rmani')

# %%
os.listdir()
# Out:
# ['.bash_history',
#  '.conda',
#  '.gitconfig',
#  '.google-cookie',
#  '.idlerc',
#  '.instagramy_cache',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.lesshst',
#  '.matplotlib',
#  '.pipwin',
#  '.surprise_data',
#  '.viminfo',
#  '.vscode',
#  '.~Untitled125.ipynb',
#  '18th Sep Python Practice.ipynb',
#  '2.Chapter-2.ipynb',
#  '3.Chapter_2_ControlStatements.ipynb',
#  '3.Numpy.ipynb',
#  '3D Objects',
#  '50_AdAgency.csv',
#  'advance_function.ipynb',
#  'akshat_first_class.ipynb',
#  'alphabet_pattern.ipynb',
#  'anaconda3',
#  'analysis2.xlsx',
#  'anatomy.jpg',
#  'AppData',
#  'Application Data',
#  'application_record.csv',
#  'Assignment_1.ipynb',
#  'aw.png',
#  'aws.png',
#  'bank.csv',
#  'bank.py',
#  'bankdata.txt',
#  'bank_app.ipynb',
#  'Bank_Application_final.ipynb',
#  'bank_application_roshni.ipynb',
#  'bank_project.ipynb',
#  'bar.ipynb',
#  'barchart.png',
#  'barchart1.png',
#  'basic_socket.ipynb',
#  'birthday.ipynb',
# ...

# %%
p1='C:\\Users\\rmani'
p2='Desktop\\Django\\tarun.txt'

# %%
p1
# Out:
# 'C:\\Users\\rmani'

# %%
p2
# Out:
# 'Desktop\\Django\\tarun.txt'

# %%
os.path.join(p1,p2)
# Out:
# 'C:\\Users\\rmani\\Desktop\\Django\\tarun.txt'

# %%
os.path.dirname(p1)
# Out:
# 'C:\\Users'

# %%
os.path.basename(p2)
# Out:
# 'tarun.txt'
